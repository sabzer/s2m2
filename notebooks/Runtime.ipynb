# %% [markdown]
# # This notebook dissects the run times of S2M2 for potential improvement ideas

# %%
from time import time

# %%
import numpy as np
import sys
sys.path.append('../')
from testSim import test
# %load_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Simulate

# %%
env = 'zigzag'
time_pos = test(env, "../problems/{}/problem.yaml".format(env), "../problems/{}/config.yaml".format(env))
# Out:
# ----- 0 -----
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.03097458599950187 s
# [0] [0.0, 40.0, 5.0]
# [1] [11.640400602418026, 28.359599397581974, 11.238279054022332]
# [2] [11.64040060241803, 28.359599397581967, 11.238279054022325]
# [3] [17.499999999999996, 22.5, 14.621320343559645]
# [4] [26.640400602418033, 13.359599397581967, 11.238279054022325]
# [5] [32.5, 7.499999999999998, 14.621320343559644]
# [6] [40.0, 0.0, 12.878679656440355]
# [7] [51.16724432600957, -10.0, 20.0]
# - Feasible Plan Found with Single-agent Travel Time 51.16724432600957
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.005073230997368228 s
# [0] [0.0, 40.0, 20.0]
# [1] [11.1672443260096, 29.999999999999982, 12.87867965644034]
# [2] [18.66724432600958, 22.5, 14.621320343559645]
# [3] [27.807644928427614, 13.359599397581967, 11.238279054022325]
# [4] [33.66724432600958, 7.499999999999998, 14.621320343559644]
# [5] [47.28930271900026, -6.122058392990683, 6.756621263449675]
# [6] [50.74955216148026, -9.58230783547068, 4.758845316370598]
# [7] [51.16724432600958, -10.0, 5.0]
# - Feasible Plan Found with Single-agent Travel Time 51.16724432600958
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.03121456900043995 s
# [0] [0.0, -10.0, 5.0]
# [1] [11.334628716059148, 1.3346287160591483, 11.544050940381206]
# [2] [17.5, 7.499999999999998, 14.621320343559644]
# [3] [23.359599397581967, 13.359599397581965, 11.238279054022321]
# [4] [31.299143414263405, 21.299143414263405, 15.82217692929624]
# [5] [40.0, 30.0, 12.878679656440358]
# [6] [44.356215129514226, 33.18897080350466, 16.067650459945018]
# [7] [51.167244326009566, 40.0, 20.0]
# - Feasible Plan Found with Single-agent Travel Time 51.167244326009566
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.026664724999136524 s
# [0] [0.0, -10.0, 20.0]
# [1] [11.167244326009572, 0.0, 12.878679656440358]
# [2] [11.167244326009573, 0.0, 12.878679656440358]
# [3] [17.02684372359154, 5.859599397581967, 16.261720945977675]
# [4] [26.767672618877867, 15.600428292868294, 10.637850761154032]
# [5] [33.66724432600957, 22.5, 14.621320343559645]
# [6] [39.52684372359154, 28.35959939758197, 11.238279054022328]
# [7] [51.16724432600957, 40.0, 5.0]
# - Feasible Plan Found with Single-agent Travel Time 51.16724432600957
#
# ----- 1 -----
# Orders: []
# Makespan = 204.6689773040383
#  -- [\] Update Colliding Agents. 0 - 1
#  -- [\] Update Colliding Agents. 2 - 3
# Collision check time: 0.0012919669970870018 Colliding Agents: (2, 3)
#
# [*] Split on (2 < 3)
# Adding Order Status:  added
# Agents to Update: [3]
# - Update Plan for Agent 3
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.12410743099826504 s
# [0] [0.0, -10.0, 20.0]
# [1] [20.46689773040383, -3.865993371555188, 12.006726693819688]
# [2] [30.70034659560575, 1.6404006024180262, 11.238279054022328]
# [3] [36.559945993187725, 7.499999999999998, 14.621320343559644]
# [4] [44.059945993187725, 14.999999999999998, 12.878679656440355]
# [5] [51.559945993187725, 22.5, 14.621320343559645]
# [6] [54.72892239879336, 25.668976405605633, 12.79171096272766]
# [7] [61.48867935136302, 32.42873335817529, 8.888963466505121]
# [8] [69.05994599318772, 40.0, 5.0]
# - Feasible Plan Found with Single-agent Travel Time 69.05994599318772
# - Update Succeed for Agent 3
# Feasible and Push
#
# [*] Split on (3 < 2)
# Adding Order Status:  added
# Agents to Update: [2]
# - Update Plan for Agent 2
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.10823681900001247 s
# [0] [0.0, -10.0, 5.0]
# [1] [20.46689773040383, -1.7326281578380716, 9.87767965644036]
# [2] [30.70034659560573, 7.155007743609055, 16.562969590405654]
# [3] [39.74619543773326, 16.200856585736588, 11.677823070703766]
# [4] [47.68573945441471, 24.140400602418033, 16.26172094597768]
# [5] [53.545338851996675, 30.0, 12.878679656440356]
# [6] [61.15661210557802, 36.999, 17.626546446044138]
# [7] [61.15661210557803, 36.999, 17.626546446044134]
# [8] [64.71258317800627, 40.0, 20.0]
# - Feasible Plan Found with Single-agent Travel Time 64.71258317800627
# - Update Succeed for Agent 2
# Feasible and Push
#
# ----- 2 -----
# Orders: [(3, 2)]
# Makespan = 218.214316156035
#  -- [\] Update Colliding Agents. 0 - 1
# Collision check time: 0.0005281559970171656 Colliding Agents: (0, 1)
#
# [*] Split on (0 < 1)
# Adding Order Status:  added
# Agents to Update: [1]
# - Update Plan for Agent 1
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.1421417650017247 s
# [0] [0.0, 40.0, 20.0]
# [1] [20.466897730403826, 33.829201589433914, 11.711818520542565]
# [2] [27.174778976278095, 27.121320343559645, 10.000000000000002]
# [3] [30.700346595605737, 28.35959939758197, 11.238279054022328]
# [4] [36.55994599318771, 22.5, 14.621320343559645]
# [5] [44.05994599318771, 14.999999999999998, 12.878679656440356]
# [6] [51.55994599318771, 7.499999999999998, 14.621320343559644]
# [7] [59.29411973139081, 0.275479693656057, 9.861744507771455]
# [8] [69.56959942504686, -10.0, 5.0]
# - Feasible Plan Found with Single-agent Travel Time 69.56959942504686
# - Update Succeed for Agent 1
# Feasible and Push
#
# [*] Split on (1 < 0)
# Adding Order Status:  added
# Agents to Update: [0]
# - Update Plan for Agent 0
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.11995040799956769 s
# [0] [0.0, 40.0, 5.0]
# [1] [5.116724432600961, 35.82872896128915, 1.5]
# [2] [20.46689773040383, 31.4145380731815, 5.706782270378145]
# [3] [33.66724432600958, 28.35959939758223, 11.238279054022781]
# [4] [39.526843723591284, 22.5, 14.621320343559645]
# [5] [47.026843723591284, 14.999999999999998, 12.878679656440356]
# [6] [54.526843723591284, 7.499999999999998, 14.621320343559644]
# [7] [62.026843723591284, 0.0, 12.878679656440358]
# [8] [73.19408804960085, -10.0, 20.0]
# - Feasible Plan Found with Single-agent Travel Time 73.19408804960085
# - Update Succeed for Agent 0
# Feasible and Push
#
# ----- 3 -----
# Orders: [(0, 1), (3, 2)]
# Makespan = 236.61667125507228
#  -- [\] Update Colliding Agents. 0 - 2
#  -- [\] Update Colliding Agents. 0 - 3
# Collision check time: 0.0026861469996219967 Colliding Agents: (0, 3)
#
# [*] Split on (0 < 3)
# Adding Order Status:  added
# Agents to Update: [3]
# - Update Plan for Agent 3
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.11483136099923286 s
# [0] [0.0, -10.0, 20.0]
# [1] [40.0, -1.4166569461293417, 5.7159015037502625]
# [2] [52.565468358901356, 6.898121637249003, 15.424714929398345]
# [3] [60.667346721652336, 14.999999999999991, 12.878679656440347]
# [4] [68.16734672165235, 22.499999999999996, 14.621320343559649]
# [5] [78.0102816231724, 32.34293490152004, 8.93849922855108]
# [6] [85.66734672165236, 40.0, 5.0]
# - Feasible Plan Found with Single-agent Travel Time 85.66734672165236
# - Update Succeed for Agent 3
# Feasible and Push
#
# [*] Split on (3 < 0)
# Adding Order Status:  added
# Agents to Update: [0]
# - Update Plan for Agent 0
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.138259138999274 s
# [0] [0.0, 40.0, 5.0]
# [1] [2.7501571637670477, 39.99999999999999, 1.824392042370634]
# [2] [2.7501571637670494, 40.000000000000014, 1.8243920423706403]
# [3] [10.233448865201922, 32.51670829856514, 6.144872520618562]
# [4] [25.583622163004776, 20.303115526485794, 16.818204817073845]
# [5] [33.66724432600958, 17.07682608052352, 14.955505736963879]
# [6] [40.105669804115074, 12.363571509804357, 10.242251166244717]
# [7] [47.59943739306788, 6.570590723972493, 15.55072961958715]
# [8] [54.170028117040374, 0.0, 12.878679656440358]
# [9] [65.33727244304995, -10.0, 20.0]
# - Feasible Plan Found with Single-agent Travel Time 65.33727244304995
# - Update Succeed for Agent 0
# Feasible and Push
#
# ----- 4 -----
# Orders: [(0, 1), (3, 2), (3, 0)]
# Makespan = 250.78669937211265
#  -- [\] Update Colliding Agents. 0 - 2
#  -- [\] Update Colliding Agents. 1 - 3
# Collision check time: 0.002622528001666069 Colliding Agents: (1, 3)
#
# [*] Split on (1 < 3)
# Adding Order Status:  inconsistent
# Infeasible
#
# [*] Split on (3 < 1)
# Adding Order Status:  existing
# Agents to Update: [1]
# - Update Plan for Agent 1
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.6081675579989678 s
# [0] [0.0, 40.0, 20.0]
# [1] [46.05051989340863, 30.576379083789874, 13.455058740230232]
# [2] [46.837868364075604, 30.0, 12.878679656440356]
# [3] [52.929628290001254, 24.774674961364987, 16.89599530492464]
# [4] [61.7436550133552, 15.96064823801104, 11.807214603551682]
# [5] [69.06314703594872, 8.641156215417524, 15.76247655897717]
# [6] [78.92883333021884, -1.2245300788525908, 10.066519921239918]
# [7] [81.6911107030122, -3.9868074516459555, 8.471718336481258]
# [8] [87.70430325136624, -10.0, 5.0]
# - Feasible Plan Found with Single-agent Travel Time 87.70430325136624
# - Update Succeed for Agent 1
# Feasible and Push
#
# ----- 5 -----
# Orders: [(0, 1), (3, 2), (3, 0)]
# Makespan = 268.921403198432
#  -- [\] Update Colliding Agents. 0 - 2
# Collision check time: 0.0014166930013743695 Colliding Agents: (0, 2)
#
# [*] Split on (0 < 2)
# Adding Order Status:  added
# Agents to Update: [2]
# - Update Plan for Agent 2
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.4058932480002113 s
# [0] [0.0, -10.0, 5.0]
# [1] [15.350173297802872, -5.460116675448136, 7.418562980992223]
# [2] [27.765287032789583, -2.1518123354135192, 10.72686732102684]
# [3] [40.10566980411508, 8.471387697333125, 18.843006552320915]
# [4] [48.53523456375587, 14.999999999999991, 12.878679656440347]
# [5] [54.59852119495535, 20.3031155264858, 16.818204817073845]
# [6] [64.29540566846956, 30.0, 12.878679656440358]
# [7] [75.46264999447914, 40.0, 20.0]
# - Feasible Plan Found with Single-agent Travel Time 75.46264999447914
# - Update Succeed for Agent 2
# Feasible and Push
#
# [*] Split on (2 < 0)
# Adding Order Status:  added
# Agents to Update: [0]
# - Update Plan for Agent 0
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.8355516500014346 s
# [0] [0.0, 40.0, 5.0]
# [1] [21.136951250148602, 28.07992576305151, 10.958605419491867]
# [2] [30.70034659560573, 20.33133035991914, 17.52780953178488]
# [3] [47.685739454414716, 18.71722668294156, 16.59590633938192]
# [4] [56.36499382780655, 12.363571509804357, 10.242251166244714]
# [5] [57.56001537436415, 11.215652713234078, 10.9593919632219]
# [6] [62.58916473519288, 7.499999999999998, 14.621320343559644]
# [7] [70.08916473519288, 0.0, 12.878679656440358]
# [8] [81.25640906120245, -10.0, 20.0]
# - Feasible Plan Found with Single-agent Travel Time 81.25640906120245
# - Update Succeed for Agent 0
# Feasible and Push
#
# ----- 6 -----
# Orders: [(0, 1), (0, 2), (3, 2), (3, 0)]
# Makespan = 279.6714700149049
#  -- [\] Update Colliding Agents. 1 - 2
# Collision check time: 0.0009702099996502511 Colliding Agents: (1, 2)
#
# [*] Split on (1 < 2)
# Adding Order Status:  added
# Agents to Update: [2]
# - Update Plan for Agent 2
# - Find Collision and Reroute
# Printing Solution with Solving Time  4.941763088001608 s
# [0] [0.0, -10.0, 5.0]
# [1] [20.46689773040383, -1.7326281578380707, 9.87767965644036]
# [2] [32.82093431817913, 7.37336294483691, 18.88554594113373]
# [3] [47.59943739306788, 8.084627908758202, 19.794051747682154]
# [4] [61.39301227595637, 13.025414004177733, 9.095906339381909]
# [5] [69.06314703594873, 13.00148605611119, 9.137350761154032]
# [6] [76.22514871358004, 20.163487733742503, 13.272334357671012]
# [7] [78.56166097983753, 22.499999999999986, 14.621320343559638]
# [8] [84.60415402695857, 27.859924654659505, 10.738604311099877]
# [9] [98.694795640716, 40.0, 20.0]
# - Feasible Plan Found with Single-agent Travel Time 98.694795640716
# - Update Succeed for Agent 2
# Feasible and Push
#
# [*] Split on (2 < 1)
# Adding Order Status:  added
# Agents to Update: [1]
# - Update Plan for Agent 1
# - Find Collision and Reroute
# Printing Solution with Solving Time  0.8301693770008569 s
# [0] [0.0, 40.0, 20.0]
# [1] [11.167244326009579, 30.0, 12.878679656440358]
# [2] [26.134908977219983, 22.00089128574233, 19.87957094218269]
# [3] [60.37011999558331, 21.937990949374722, 19.649892113563123]
# [4] [69.70315747256063, 14.999999999999991, 12.87867965644035]
# [5] [75.75463073393696, 9.66460974694876, 16.785930090508405]
# [6] [85.69863784918584, -0.27939736830012896, 11.044754905695905]
# [7] [91.50997268639561, -6.090732205509908, 7.689579173081791]
# [8] [94.00049687068655, -8.477214137790394, 6.191605542652823]
# [9] [95.79385047301903, -10.0, 5.0]
# - Feasible Plan Found with Single-agent Travel Time 95.79385047301903
# - Update Succeed for Agent 1
# Feasible and Push
#
# ----- 7 -----
# Orders: [(0, 1), (0, 2), (2, 1), (3, 2), (3, 0)]
# Makespan = 287.7610172365577
# Collision check time: 1.7112000932684168e-05 Colliding Agents: None
# [*] Solution Found!
# Total Time =  9.808770760999323
